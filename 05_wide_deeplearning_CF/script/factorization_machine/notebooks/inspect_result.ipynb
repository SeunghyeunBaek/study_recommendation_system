# %%
import os, sys
PRJ_DIR = '/workspace/study_recsys/05_widedeepfm/FM'
sys.path.append(PRJ_DIR)

# %%
from module.utils import load_pickle
from module.plotter import plot_lines
train_result_path = '/workspace/study_recsys/05_widedeepfm/FM/result/train_20210322_054042.pickle'
train_result_dict = load_pickle(train_result_path)

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
epoch_range = list(range(train_result_dict['config']['TRAIN']['epoch']))
loss_plot = plot_lines(epoch_range, train_result_dict['train_loss'], train_result_dict['val_loss'])

# %%
score_plot = plot_lines(epoch_range, train_result_dict['train_score'], train_result_dict['val_score'])
